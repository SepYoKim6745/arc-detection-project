# %%
# 모듈 임포트
import time
import board
import busio
import adafruit_ads1x15.ads1115 as ADS
from adafruit_ads1x15.analog_in import AnalogIn
import joblib
import numpy as np
import psutil
import pandas as pd
from sklearn.preprocessing import StandardScaler
import csv
from datetime import datetime

# %%
# 모델 및 스케일러 로드
model = joblib.load('./model/one_class_svm_model.joblib')
scaler = joblib.load('./model/scaler.joblib')

# %%
# I2C 및 ADC 설정
i2c = busio.I2C(board.SCL, board.SDA)
ads = ADS.ADS1115(i2c) # (아날로그 → 디지털 변환기) 객체
ads.gain = 2/3 # 증폭 배율 설정

# ADS1115 채널 선택
voltage_ch = AnalogIn(ads, ADS.P0)
current_ch = AnalogIn(ads, ADS.P1)

# %%
# 센서 보정값
ZMPT_offset = 2.5539
ZMPT_scale = 997.6

ACS712_offset = 2.5087
ACS712_sensitivity = 0.0990

# %%
# 파생 피처 생성 함수
def add_features(voltage_seq, current_seq):
    voltage = np.mean(voltage_seq)
    current = np.mean(current_seq)
    voltage_diff = np.abs(voltage_seq[-1] - voltage_seq[-2])
    current_diff = np.abs(current_seq[-1] - current_seq[-2])
    voltage_ma = np.mean(voltage_seq[-5:])
    current_ma = np.mean(current_seq[-5:])
    power = voltage * current
    power_diff = np.abs(power - (voltage_seq[-2] * current_seq[-2]))
    return [voltage, current, voltage_diff, current_diff, voltage_ma, current_ma, power, power_diff]

# %%
def postprocess_anomalies_realtime(anomaly_buffer, min_consecutive=8):
    if len(anomaly_buffer) < min_consecutive:
        return False
    
    # 정확히 연속된 1이 min_consecutive 이상인지 확인
    count = 0
    for val in reversed(anomaly_buffer): # 최근 값부터 역순으로 확인
        if val == 1:
            count += 1
        else:
            break
    
    return count >= min_consecutive

# %%
# 테스트 데이터 불러오기 (센서 대체)
column_names = ['timestamp', 'v_raw', 'c_raw', 'voltage', 'current']
df = pd.read_csv('../../data/test/test_dataset_187.csv', names=column_names, header=None)
df = df.dropna(subset=['voltage', 'current']).reset_index(drop=True)
csv_filename = "./log/svm_log1(0506).csv"

# %%
try:
    print("🚀 실시간 아크 감지 시작합니다!")

    USE_SENSOR = True  # True로 설정 시 실제 센서 사용
    ANOMALY_THRESHOLD = 2

    data_buffer = []
    anomaly_buffer = []
    first_anomaly_detected = False
    anomaly_start_time = None
    start_time = time.perf_counter()
    idx = -1

    while True:
        idx += 1

        if USE_SENSOR:
            try:
                v_raw_sensor = voltage_ch.voltage
                c_raw_sensor = current_ch.voltage
                voltage = (v_raw_sensor - ZMPT_offset) * ZMPT_scale
                current = (c_raw_sensor - ACS712_offset) / ACS712_sensitivity

                prev_voltage = voltage
                prev_current = current

            except (OSError, ValueError, RuntimeError) as e:
                print(f"⚠️ 센서 오류 발생: {e}")
                print("🩹 이전 정상값을 사용합니다.")
                voltage = prev_voltage if 'prev_voltage' in locals() else 0
                current = prev_current if 'prev_current' in locals() else 0

        else:
            voltage = df['voltage'].iloc[idx]
            current = df['current'].iloc[idx]

        data_buffer.append((voltage, current))

        anomaly = 0
        if len(data_buffer) >= 8:
            voltage_seq, current_seq = zip(*data_buffer[-8:])
            features = add_features(voltage_seq, current_seq)
            features_scaled = scaler.transform([features])
            anomaly = int(model.predict(features_scaled).flatten()[0])
            anomaly = int(anomaly == -1)  # 이상이면 1, 아니면 0

            anomaly_buffer.append(anomaly)
            if len(anomaly_buffer) > ANOMALY_THRESHOLD:
                anomaly_buffer.pop(0)

            # 첫 이상 신호 시간 기록
            if anomaly == 1 and anomaly_start_time is None:
                anomaly_start_time = time.perf_counter()
            elif anomaly == 0:
                anomaly_start_time = None

            if postprocess_anomalies_realtime(anomaly_buffer, min_consecutive=ANOMALY_THRESHOLD):
                print("⚡ 아크 이상 감지!", idx)
                if not first_anomaly_detected and anomaly_start_time is not None:
                    total_elapsed = time.perf_counter() - start_time
                    actual_elapsed = time.perf_counter() - anomaly_start_time
                    print(f"⏱️ 전체 소요 시간: {total_elapsed:.6f}초")
                    print(f"⏱️ 연속 2개 이상 신호까지 실제 소요 시간: {actual_elapsed:.6f}초")
                    first_anomaly_detected = True

                    # 아크 발생 직전에 CSV 기록
                    with open(csv_filename, mode='a', newline='') as file:
                        writer = csv.writer(file)
                        timestamp = datetime.now().isoformat()
                        writer.writerow([timestamp, voltage, current, anomaly])
                    
                    break

        # CSV 기록
        with open(csv_filename, mode='a', newline='') as file:
            writer = csv.writer(file)
            timestamp = datetime.now().isoformat()
            writer.writerow([timestamp, voltage, current, anomaly])

        # 메모리 및 CPU 사용량 출력
        process = psutil.Process()
        cpu_usage = process.cpu_percent(interval=0.0)
        # cpu_usage = psutil.cpu_percent(interval=0.0)
        memory_usage = psutil.Process().memory_info().rss / 1024 ** 2
        print(f"🧠 메모리: {memory_usage:.2f}MB | 🧮 CPU: {cpu_usage:.2f}% | idx: {idx}")
        print(f"v_raw:{v_raw_sensor}, c_raw:{c_raw_sensor}, voltage:{voltage}, current:{current}")

        time.sleep(0.001163)  # 860Hz 간격

except KeyboardInterrupt:
    print("🛑 실시간 감지를 종료합니다.")
# Out:
# 🚀 실시간 아크 감지 시작합니다!
# 🧠 메모리: 181.93MB | 🧮 CPU: 12.90% | idx: 0
# v_raw:2.5095, c_raw:2.558625, voltage:-44.29344, current:0.5042929292929292
# 🧠 메모리: 182.06MB | 🧮 CPU: 12.50% | idx: 1
# v_raw:2.5629375, c_raw:2.557875, voltage:9.01580999999981, current:0.4967171717171714
# 🧠 메모리: 182.06MB | 🧮 CPU: 0.00% | idx: 2
# v_raw:2.5588125, c_raw:2.5584375, voltage:4.900710000000097, current:0.5023989898989898
# 🧠 메모리: 182.06MB | 🧮 CPU: 0.00% | idx: 3
# v_raw:2.5524375, c_raw:2.55825, voltage:-1.458990000000144, current:0.5005050505050503
# 🧠 메모리: 182.06MB | 🧮 CPU: 11.10% | idx: 4
# v_raw:2.547, c_raw:2.558625, voltage:-6.883439999999907, current:0.5042929292929292
# 🧠 메모리: 182.06MB | 🧮 CPU: 11.10% | idx: 5
# v_raw:2.5456875, c_raw:2.557875, voltage:-8.192789999999956, current:0.4967171717171714
# 🧠 메모리: 182.06MB | 🧮 CPU: 0.00% | idx: 6
# v_raw:2.5445625, c_raw:2.557875, voltage:-9.31509, current:0.4967171717171714
# 🧠 메모리: 182.24MB | 🧮 CPU: 0.00% | idx: 7
# v_raw:2.54325, c_raw:2.558625, voltage:-10.624440000000048, current:0.5042929292929292
# 🧠 메모리: 182.24MB | 🧮 CPU: 0.00% | idx: 8
# v_raw:2.5395, c_raw:2.5580625, voltage:-14.36544000000019, current:0.49861111111111084
# 🧠 메모리: 182.24MB | 🧮 CPU: 20.00% | idx: 9
# v_raw:2.534625, c_raw:2.557875, voltage:-19.22873999999993, current:0.4967171717171714
# 🧠 메모리: 182.24MB | 🧮 CPU: 11.10% | idx: 10
# v_raw:2.5455, c_raw:2.5576875, voltage:-8.379839999999964, current:0.4948232323232319
# 🧠 메모리: 182.24MB | 🧮 CPU: 20.00% | idx: 11
# v_raw:2.5344375, c_raw:2.557875, voltage:-19.415789999999937, current:0.4967171717171714
# 🧠 메모리: 182.24MB | 🧮 CPU: 11.10% | idx: 12
# v_raw:2.5468125, c_raw:2.557875, voltage:-7.070489999999913, current:0.4967171717171714
# 🧠 메모리: 182.24MB | 🧮 CPU: 10.00% | idx: 13
# v_raw:2.544, c_raw:2.55825, voltage:-9.87624000000002, current:0.5005050505050503
# 🧠 메모리: 182.24MB | 🧮 CPU: 0.00% | idx: 14
# v_raw:2.54775, c_raw:2.5580625, voltage:-6.135239999999878, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 15
# v_raw:2.544375, c_raw:2.557875, voltage:-9.502140000000006, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 16
# v_raw:2.544, c_raw:2.55825, voltage:-9.87624000000002, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 17
# v_raw:2.5438125, c_raw:2.5576875, voltage:-10.063290000000027, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 18
# v_raw:2.5438125, c_raw:2.55825, voltage:-10.063290000000027, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 19
# v_raw:2.5441875, c_raw:2.5580625, voltage:-9.689190000000012, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 20
# v_raw:2.54325, c_raw:2.5580625, voltage:-10.624440000000048, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 21
# v_raw:2.54025, c_raw:2.5584375, voltage:-13.617240000000162, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 22
# v_raw:2.5449375, c_raw:2.5576875, voltage:-8.940989999999985, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 23
# v_raw:2.5419375, c_raw:2.5584375, voltage:-11.933790000000098, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 24
# v_raw:2.5449375, c_raw:2.558625, voltage:-8.940989999999985, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 25
# v_raw:2.543625, c_raw:2.5580625, voltage:-10.250340000000035, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 26
# v_raw:2.5430625, c_raw:2.55825, voltage:-10.811490000000056, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 27
# v_raw:2.5336875, c_raw:2.5580625, voltage:-20.163989999999966, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 28
# v_raw:2.5370625, c_raw:2.5576875, voltage:-16.79708999999984, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 29
# v_raw:2.536125, c_raw:2.557875, voltage:-17.732339999999876, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 30
# v_raw:2.541375, c_raw:2.5576875, voltage:-12.494940000000119, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 31
# v_raw:2.5468125, c_raw:2.55825, voltage:-7.070489999999913, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 32
# v_raw:2.5438125, c_raw:2.5576875, voltage:-10.063290000000027, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 33
# v_raw:2.54475, c_raw:2.5575, voltage:-9.128039999999991, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 34
# v_raw:2.5445625, c_raw:2.5580625, voltage:-9.31509, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 35
# v_raw:2.54625, c_raw:2.5573125, voltage:-7.631639999999935, current:0.491035353535353
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 36
# v_raw:2.5438125, c_raw:2.5576875, voltage:-10.063290000000027, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 37
# v_raw:2.5430625, c_raw:2.5575, voltage:-10.811490000000056, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 38
# v_raw:2.533125, c_raw:2.5580625, voltage:-20.72513999999999, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 39
# v_raw:2.54475, c_raw:2.557875, voltage:-9.128039999999991, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 40
# v_raw:2.5471875, c_raw:2.557875, voltage:-6.6963899999999, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 41
# v_raw:2.543625, c_raw:2.5575, voltage:-10.250340000000035, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 42
# v_raw:2.545125, c_raw:2.5575, voltage:-8.753939999999977, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 43
# v_raw:2.5370625, c_raw:2.5575, voltage:-16.79708999999984, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 44
# v_raw:2.5372500000000002, c_raw:2.5573125, voltage:-16.61003999999983, current:0.491035353535353
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 45
# v_raw:2.5381875000000003, c_raw:2.5575, voltage:-15.674789999999797, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 46
# v_raw:2.54625, c_raw:2.5580625, voltage:-7.631639999999935, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 47
# v_raw:2.5355625, c_raw:2.557875, voltage:-18.293489999999895, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 48
# v_raw:2.54775, c_raw:2.5575, voltage:-6.135239999999878, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 49
# v_raw:2.536875, c_raw:2.5576875, voltage:-16.984139999999847, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 50
# v_raw:2.536875, c_raw:2.5580625, voltage:-16.984139999999847, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 51
# v_raw:2.5453125, c_raw:2.5575, voltage:-8.56688999999997, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 52
# v_raw:2.5441875, c_raw:2.557875, voltage:-9.689190000000012, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 53
# v_raw:2.546625, c_raw:2.557875, voltage:-7.257539999999921, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 54
# v_raw:2.54325, c_raw:2.5575, voltage:-10.624440000000048, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 55
# v_raw:2.54325, c_raw:2.5575, voltage:-10.624440000000048, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 56
# v_raw:2.5359375, c_raw:2.557875, voltage:-17.919389999999883, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 57
# v_raw:2.5438125, c_raw:2.5580625, voltage:-10.063290000000027, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 58
# v_raw:2.5449375, c_raw:2.5580625, voltage:-8.940989999999985, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 59
# v_raw:2.5434375, c_raw:2.5580625, voltage:-10.437390000000041, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 60
# v_raw:2.5438125, c_raw:2.557875, voltage:-10.063290000000027, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 12.50% | idx: 61
# v_raw:2.5164375, c_raw:2.557875, voltage:-37.37259000000018, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 62
# v_raw:2.547375, c_raw:2.557875, voltage:-6.509339999999892, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 63
# v_raw:2.54475, c_raw:2.5580625, voltage:-9.128039999999991, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 22.20% | idx: 64
# v_raw:2.5464375, c_raw:2.5580625, voltage:-7.444589999999928, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 25.00% | idx: 65
# v_raw:2.5059375, c_raw:2.55825, voltage:-47.84739000000013, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 33.30% | idx: 66
# v_raw:2.513625, c_raw:2.5580625, voltage:-40.17833999999984, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 33.30% | idx: 67
# v_raw:2.5209375, c_raw:2.5576875, voltage:-32.883390000000006, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 30.00% | idx: 68
# v_raw:2.5254375000000002, c_raw:2.557875, voltage:-28.394189999999835, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 69
# v_raw:2.5575, c_raw:2.5580625, voltage:3.5913600000000474, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 70
# v_raw:2.551125, c_raw:2.557875, voltage:-2.7683400000001934, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 71
# v_raw:2.5374375000000002, c_raw:2.5584375, voltage:-16.422989999999825, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 72
# v_raw:2.5471875, c_raw:2.5580625, voltage:-6.6963899999999, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 73
# v_raw:2.543625, c_raw:2.55825, voltage:-10.250340000000035, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 74
# v_raw:2.54775, c_raw:2.557875, voltage:-6.135239999999878, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 75
# v_raw:2.544375, c_raw:2.557875, voltage:-9.502140000000006, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 76
# v_raw:2.5438125, c_raw:2.5576875, voltage:-10.063290000000027, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 77
# v_raw:2.5471875, c_raw:2.5580625, voltage:-6.6963899999999, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 78
# v_raw:2.542875, c_raw:2.5575, voltage:-10.998540000000062, current:0.49292929292929244
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 79
# v_raw:2.5456875, c_raw:2.55825, voltage:-8.192789999999956, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 80
# v_raw:2.5438125, c_raw:2.557875, voltage:-10.063290000000027, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 81
# v_raw:2.551875, c_raw:2.5584375, voltage:-2.0201400000001652, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 18.20% | idx: 82
# v_raw:2.5486875, c_raw:2.55825, voltage:-5.1999899999998425, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 83
# v_raw:2.5449375, c_raw:2.558625, voltage:-8.940989999999985, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 84
# v_raw:2.5485, c_raw:2.5580625, voltage:-5.38703999999985, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 85
# v_raw:2.5501875000000003, c_raw:2.55825, voltage:-3.703589999999786, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 86
# v_raw:2.5445625, c_raw:2.5580625, voltage:-9.31509, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 87
# v_raw:2.5471875, c_raw:2.55825, voltage:-6.6963899999999, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 88
# v_raw:2.5483125, c_raw:2.5580625, voltage:-5.574089999999857, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 89
# v_raw:2.547, c_raw:2.5580625, voltage:-6.883439999999907, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 90
# v_raw:2.5471875, c_raw:2.55825, voltage:-6.6963899999999, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 91
# v_raw:2.6535, c_raw:2.557875, voltage:99.36096000000013, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 92
# v_raw:2.4671250000000002, c_raw:2.5580625, voltage:-86.56673999999983, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 93
# v_raw:2.34525, c_raw:2.5580625, voltage:-208.14924000000002, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 94
# v_raw:2.9229375, c_raw:2.557875, voltage:368.1518100000001, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 95
# v_raw:2.3272500000000003, c_raw:2.5584375, voltage:-226.1060399999998, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 96
# v_raw:2.3030625000000002, c_raw:2.558625, voltage:-250.23548999999983, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 25.00% | idx: 97
# v_raw:2.9221875, c_raw:2.5580625, voltage:367.4036100000001, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 98
# v_raw:2.541, c_raw:2.559, voltage:-12.869040000000133, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 99
# v_raw:2.2854375, c_raw:2.559375, voltage:-267.8181900000001, current:0.5118686868686871
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 100
# v_raw:2.919375, c_raw:2.558625, voltage:364.59786, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 101
# v_raw:2.310375, c_raw:2.5588125, voltage:-242.94054, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 102
# v_raw:2.375625, c_raw:2.559375, voltage:-177.8471400000002, current:0.5118686868686871
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 103
# v_raw:2.92125, c_raw:2.559, voltage:366.4683600000001, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 104
# v_raw:2.31225, c_raw:2.5588125, voltage:-241.07003999999992, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 27.30% | idx: 105
# v_raw:2.4271875, c_raw:2.5580625, voltage:-126.40839000000001, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 18.20% | idx: 106
# v_raw:2.9133750000000003, c_raw:2.557875, voltage:358.6122600000002, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 107
# v_raw:2.208, c_raw:2.559, voltage:-345.0698399999999, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 108
# v_raw:2.7765, c_raw:2.5588125, voltage:222.06575999999993, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 109
# v_raw:2.380125, c_raw:2.5591875, voltage:-173.35794, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 110
# v_raw:2.651625, c_raw:2.558625, voltage:97.49046000000007, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 18.20% | idx: 111
# v_raw:2.829375, c_raw:2.5591875, voltage:274.81386000000015, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 112
# v_raw:2.17575, c_raw:2.558625, voltage:-377.2424400000002, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 113
# v_raw:2.7399375, c_raw:2.559, voltage:185.59100999999987, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 114
# v_raw:2.712, c_raw:2.559375, voltage:157.72056000000012, current:0.5118686868686871
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 115
# v_raw:2.190375, c_raw:2.559, voltage:-362.6525400000001, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 116
# v_raw:2.8336875, c_raw:2.5591875, voltage:279.11600999999985, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 117
# v_raw:2.5918125, c_raw:2.5588125, voltage:37.82151000000002, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 118
# v_raw:2.4346875, c_raw:2.55825, voltage:-118.92639000000017, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 119
# v_raw:2.700375, c_raw:2.5584375, voltage:146.12346000000014, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 120
# v_raw:2.3593125, c_raw:2.5591875, voltage:-194.1204899999999, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 25.00% | idx: 121
# v_raw:2.817, c_raw:2.559375, voltage:262.46856000000014, current:0.5118686868686871
# 🧠 메모리: 182.36MB | 🧮 CPU: 11.10% | idx: 122
# v_raw:2.1871875, c_raw:2.559, voltage:-365.8323900000002, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 123
# v_raw:2.6248125, c_raw:2.5591875, voltage:70.74230999999993, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 124
# v_raw:2.8179375, c_raw:2.5591875, voltage:263.40381000000014, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 125
# v_raw:2.183625, c_raw:2.5588125, voltage:-369.3863399999999, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 126
# v_raw:2.6585625, c_raw:2.559375, voltage:104.41130999999989, current:0.5118686868686871
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 127
# v_raw:2.7988125, c_raw:2.559, voltage:244.32470999999987, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 128
# v_raw:2.179875, c_raw:2.5591875, voltage:-373.12734000000006, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 129
# v_raw:2.704875, c_raw:2.5595625, voltage:150.61265999999986, current:0.5137626262626266
# 🧠 메모리: 182.36MB | 🧮 CPU: 23.10% | idx: 130
# v_raw:2.8648125, c_raw:2.559375, voltage:310.1663100000002, current:0.5118686868686871
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 131
# v_raw:2.311125, c_raw:2.55975, voltage:-242.19233999999997, current:0.515656565656566
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 132
# v_raw:2.4106875, c_raw:2.559, voltage:-142.8687900000002, current:0.5080808080808081
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 133
# v_raw:2.9210625, c_raw:2.55975, voltage:366.2813100000001, current:0.515656565656566
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 134
# v_raw:2.324625, c_raw:2.5595625, voltage:-228.7247399999999, current:0.5137626262626266
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 135
# v_raw:2.42325, c_raw:2.5595625, voltage:-130.33644000000015, current:0.5137626262626266
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 136
# v_raw:2.9161875, c_raw:2.5591875, voltage:361.41800999999987, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 23.10% | idx: 137
# v_raw:2.2719375, c_raw:2.5588125, voltage:-281.28579000000013, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 138
# v_raw:2.4845625, c_raw:2.55825, voltage:-69.17109000000005, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 139
# v_raw:2.8569375, c_raw:2.557875, voltage:302.31020999999987, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 140
# v_raw:2.173125, c_raw:2.5584375, voltage:-379.86113999999986, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 141
# v_raw:2.7455625, c_raw:2.5584375, voltage:191.20251000000007, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 142
# v_raw:2.7050625, c_raw:2.5576875, voltage:150.79970999999986, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 143
# v_raw:2.17875, c_raw:2.557875, voltage:-374.2496400000001, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 144
# v_raw:2.7946875, c_raw:2.55825, voltage:240.20961000000017, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 145
# v_raw:2.6345625, c_raw:2.5576875, voltage:80.46890999999987, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 18.20% | idx: 146
# v_raw:2.1738750000000002, c_raw:2.5584375, voltage:-379.11293999999987, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 147
# v_raw:2.788125, c_raw:2.558625, voltage:233.6628599999999, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 23.10% | idx: 148
# v_raw:2.5636875, c_raw:2.558625, voltage:9.764009999999839, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 30.00% | idx: 149
# v_raw:2.165625, c_raw:2.55825, voltage:-387.3431400000002, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 150
# v_raw:2.82525, c_raw:2.557875, voltage:270.69876, current:0.4967171717171714
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 151
# v_raw:2.6214375, c_raw:2.5580625, voltage:67.3754099999998, current:0.49861111111111084
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 152
# v_raw:2.19, c_raw:2.55825, voltage:-363.0266400000001, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 153
# v_raw:2.847, c_raw:2.55825, voltage:292.3965599999999, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 154
# v_raw:2.6319375000000003, c_raw:2.55825, voltage:77.8502100000002, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 155
# v_raw:2.1885, c_raw:2.55825, voltage:-364.52304000000015, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 156
# v_raw:2.6465625, c_raw:2.55825, voltage:92.44010999999988, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 157
# v_raw:2.840625, c_raw:2.5591875, voltage:286.0368600000001, current:0.5099747474747477
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 158
# v_raw:2.194875, c_raw:2.5588125, voltage:-358.16333999999995, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 159
# v_raw:2.5663125, c_raw:2.55825, voltage:12.382709999999937, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 160
# v_raw:2.8576875, c_raw:2.5584375, voltage:303.05840999999987, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 161
# v_raw:2.192625, c_raw:2.55825, voltage:-360.40794, current:0.5005050505050503
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 162
# v_raw:2.62125, c_raw:2.45475, voltage:67.1883599999998, current:-0.5449494949494943
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 163
# v_raw:2.8824375, c_raw:2.7898125, voltage:327.74900999999994, current:2.839520202020201
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 164
# v_raw:2.252625, c_raw:2.5018125, voltage:-300.55193999999995, current:-0.06957070707070641
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 165
# v_raw:2.5235625, c_raw:2.3934375, voltage:-30.264689999999906, current:-1.1642676767676772
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 166
# v_raw:2.8575, c_raw:2.5576875, voltage:302.87135999999987, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 167
# v_raw:2.2215000000000003, c_raw:2.4118125, voltage:-331.6022399999998, current:-0.9786616161616185
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 168
# v_raw:2.6475, c_raw:2.5040625, voltage:93.3753599999999, current:-0.04684343434343731
# 🧠 메모리: 182.36MB | 🧮 CPU: 18.20% | idx: 169
# v_raw:2.791875, c_raw:2.790375, voltage:237.40386000000007, current:2.845202020202019
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 170
# v_raw:2.2198125, c_raw:2.48175, voltage:-333.2856899999999, current:-0.27222222222222475
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 171
# v_raw:2.4305625, c_raw:2.356125, voltage:-123.04148999999988, current:-1.5411616161616173
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 172
# v_raw:2.9158125, c_raw:2.751, voltage:361.04390999999987, current:2.447474747474745
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 173
# v_raw:2.3285625, c_raw:2.5678125, voltage:-224.79669000000018, current:0.5970959595959586
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 174
# v_raw:2.4230625, c_raw:2.357625, voltage:-130.52349000000015, current:-1.5260101010101017
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 175
# v_raw:2.9150625, c_raw:2.7251250000000002, voltage:360.2957099999998, current:2.186111111111112
# 🧠 메모리: 182.36MB | 🧮 CPU: 16.70% | idx: 176
# v_raw:2.410875, c_raw:2.4463125, voltage:-142.6817400000002, current:-0.6301767676767703
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 177
# v_raw:2.427375, c_raw:2.5576875, voltage:-126.22134, current:0.4948232323232319
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 178
# v_raw:2.91675, c_raw:2.558625, voltage:361.9791599999999, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 179
# v_raw:2.2591875, c_raw:2.5584375, voltage:-294.00519000000014, current:0.5023989898989898
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 180
# v_raw:2.4920625, c_raw:2.5588125, voltage:-61.68909000000021, current:0.5061868686868687
# 🧠 메모리: 182.36MB | 🧮 CPU: 8.30% | idx: 181
# v_raw:2.8288125, c_raw:2.558625, voltage:274.2527100000001, current:0.5042929292929292
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 182
# v_raw:2.1862500000000002, c_raw:2.4174375, voltage:-366.7676399999998, current:-0.9218434343434345
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 183
# v_raw:2.6394375, c_raw:2.459625, voltage:85.33221000000005, current:-0.4957070707070727
# 🧠 메모리: 182.36MB | 🧮 CPU: 9.10% | idx: 184
# v_raw:2.8035, c_raw:2.7915, voltage:249.00096000000005, current:2.856565656565656
# 🧠 메모리: 182.36MB | 🧮 CPU: 10.00% | idx: 185
# v_raw:2.17575, c_raw:2.3626875, voltage:-377.2424400000002, current:-1.4748737373737406
# 🧠 메모리: 182.36MB | 🧮 CPU: 0.00% | idx: 186
# v_raw:2.7600000000000002, c_raw:2.61075, voltage:205.6053600000002, current:1.0308080808080782
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 187
# v_raw:2.7024375000000003, c_raw:2.7695625, voltage:148.1810100000002, current:2.634974747474747
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 188
# v_raw:2.177625, c_raw:2.3668125, voltage:-375.37194000000017, current:-1.4332070707070723
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 189
# v_raw:2.742375, c_raw:2.5276875, voltage:188.02265999999995, current:0.19179292929292638
# 🧠 메모리: 182.49MB | 🧮 CPU: 16.70% | idx: 190
# v_raw:2.7376875000000003, c_raw:2.7414375, voltage:183.34641000000022, current:2.3508838383838366
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 191
# v_raw:2.19375, c_raw:2.3371875, voltage:-359.28564, current:-1.7324494949494944
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 192
# v_raw:2.82825, c_raw:2.5968750000000003, voltage:273.6915600000001, current:0.8906565656565668
# 🧠 메모리: 182.49MB | 🧮 CPU: 16.70% | idx: 193
# v_raw:2.63775, c_raw:2.7335625, voltage:83.64875999999998, current:2.2713383838383834
# 🧠 메모리: 182.49MB | 🧮 CPU: 10.00% | idx: 194
# v_raw:2.1856875000000002, c_raw:2.3431875, voltage:-367.32878999999986, current:-1.671843434343436
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 195
# v_raw:2.77725, c_raw:2.5261875000000003, voltage:222.81395999999995, current:0.17664141414141515
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 196
# v_raw:2.747625, c_raw:2.7804375, voltage:193.26006000000015, current:2.744823232323232
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 197
# v_raw:2.1774375, c_raw:2.3904375, voltage:-375.55899000000016, current:-1.1945707070707086
# 🧠 메모리: 182.49MB | 🧮 CPU: 8.30% | idx: 198
# v_raw:2.6971875, c_raw:2.496, voltage:142.94361, current:-0.12828282828282986
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 199
# v_raw:2.7609375000000003, c_raw:2.7836250000000002, voltage:206.5406100000002, current:2.7770202020202026
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 200
# v_raw:2.178, c_raw:2.3818125, voltage:-374.9978400000001, current:-1.2816919191919196
# 🧠 메모리: 182.49MB | 🧮 CPU: 16.70% | idx: 201
# v_raw:2.70525, c_raw:2.516625, voltage:150.9867599999999, current:0.0800505050505024
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 202
# v_raw:2.8485, c_raw:2.7935625, voltage:293.89295999999996, current:2.87739898989899
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 203
# v_raw:2.1939375, c_raw:2.4253125, voltage:-359.09858999999994, current:-0.8422979797979815
# 🧠 메모리: 182.49MB | 🧮 CPU: 16.70% | idx: 204
# v_raw:2.629125, c_raw:2.4481875, voltage:75.0444600000001, current:-0.6112373737373756
# 🧠 메모리: 182.49MB | 🧮 CPU: 16.70% | idx: 205
# v_raw:2.8404375, c_raw:2.7885, voltage:285.8498100000001, current:2.8262626262626243
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 206
# v_raw:2.1856875000000002, c_raw:2.407125, voltage:-367.32878999999986, current:-1.0260101010101006
# 🧠 메모리: 182.49MB | 🧮 CPU: 8.30% | idx: 207
# v_raw:2.6656875, c_raw:2.475375, voltage:111.51921000000016, current:-0.3366161616161621
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 208
# v_raw:2.800125, c_raw:2.782875, voltage:245.63405999999992, current:2.769444444444445
# 🧠 메모리: 182.49MB | 🧮 CPU: 25.00% | idx: 209
# v_raw:2.1523125, c_raw:2.557875, voltage:-400.62369000000024, current:0.4967171717171714
# 🧠 메모리: 182.49MB | 🧮 CPU: 0.00% | idx: 210
# v_raw:2.75475, c_raw:2.557875, voltage:200.36795999999998, current:0.4967171717171714
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 211
# v_raw:2.6435625000000003, c_raw:2.5584375, voltage:89.4473100000002, current:0.5023989898989898
# 🧠 메모리: 182.49MB | 🧮 CPU: 9.10% | idx: 212
# v_raw:2.2156875, c_raw:2.55825, voltage:-337.40079000000003, current:0.5005050505050503
# ⚡ 아크 이상 감지! 213
# ⏱️ 전체 소요 시간: 5.508547초
# ⏱️ 연속 8개 이상 신호까지 실제 소요 시간: 0.028314초
