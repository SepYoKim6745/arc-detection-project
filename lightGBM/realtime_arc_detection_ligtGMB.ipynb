# %%
import time
import board
import busio
import adafruit_ads1x15.ads1115 as ADS
from adafruit_ads1x15.analog_in import AnalogIn
import joblib
import numpy as np
import psutil
import pandas as pd
from sklearn.preprocessing import StandardScaler
import csv
from datetime import datetime

# %%
# 모델 및 스케일러 로드
model = joblib.load('./model/lightgbm_model.joblib')
scaler = joblib.load('./model/scaler_lgb.joblib')

# %%
# I2C 및 ADC 설정
i2c = busio.I2C(board.SCL, board.SDA)
ads = ADS.ADS1115(i2c)
ads.gain = 1

voltage_ch = AnalogIn(ads, ADS.P0)
current_ch = AnalogIn(ads, ADS.P1)

# %%
# 센서 보정값
ZMPT_offset = 2.5539
ZMPT_scale = 997.6
ACS712_offset = 2.5087
ACS712_sensitivity = 0.0990

# %%
# 파생 피처 생성 함수
def extract_features(voltage_seq, current_seq):
    voltage = np.mean(voltage_seq)
    current = np.mean(current_seq)
    voltage_diff = np.abs(voltage_seq[-1] - voltage_seq[-2])
    current_diff = np.abs(current_seq[-1] - current_seq[-2])
    voltage_ma = np.mean(voltage_seq[-5:])
    current_ma = np.mean(current_seq[-5:])
    power = voltage * current
    power_diff = np.abs(power - (voltage_seq[-2] * current_seq[-2]))
    return [voltage, current, voltage_diff, current_diff, voltage_ma, current_ma, power, power_diff]

# %%
def postprocess_anomalies_realtime(anomaly_buffer, min_consecutive=8):
    if len(anomaly_buffer) < min_consecutive:
        return False
    count = 0
    for val in reversed(anomaly_buffer):
        if val == 1:
            count += 1
        else:
            break
    return count >= min_consecutive

# %%
# 테스트 데이터 불러오기 (CSV 대체용)
column_names = ['timestamp', 'v_raw', 'c_raw', 'voltage', 'current']
df = pd.read_csv('./log/raw_dataset_arc.csv', names=column_names, header=None)
df = df.dropna(subset=['voltage', 'current']).reset_index(drop=True)
csv_filename = "./log/lgb_log.csv"

# %%
try:
    print("🚀 LightGBM 기반 실시간 아크 감지 시작!")

    USE_SENSOR = True
    ANOMALY_THRESHOLD = 8

    data_buffer = []
    anomaly_buffer = []
    first_anomaly_detected = False
    anomaly_start_time = None
    start_time = time.perf_counter()
    idx = -1

    while True:
        idx += 1

        # 센서 or 시뮬레이션 데이터 입력
        if USE_SENSOR:
            try:
                v_raw = voltage_ch.voltage
                c_raw = current_ch.voltage
                voltage = (v_raw - ZMPT_offset) * ZMPT_scale
                current = (c_raw - ACS712_offset) / ACS712_sensitivity
                prev_voltage = voltage
                prev_current = current
            except (OSError, ValueError, RuntimeError) as e:
                print(f"⚠️ 센서 오류: {e}")
                voltage = prev_voltage if 'prev_voltage' in locals() else 0
                current = prev_current if 'prev_current' in locals() else 0
        else:
            if idx >= len(df):
                break
            voltage = df['voltage'].iloc[idx]
            current = df['current'].iloc[idx]

        data_buffer.append((voltage, current))
        if len(data_buffer) > 100:
            data_buffer.pop(0)

        anomaly = 0
        if len(data_buffer) >= 8:
            voltage_seq, current_seq = zip(*data_buffer[-8:])
            features = extract_features(voltage_seq, current_seq)
            # 모델 학습 시 사용한 컬럼 이름
            feature_names = ['voltage', 'current', 'voltage_diff', 'current_diff',
                            'voltage_ma', 'current_ma', 'power', 'power_diff']

            features_scaled = scaler.transform([features])
            features_df = pd.DataFrame(features_scaled, columns=feature_names)
            y_pred = model.predict(features_df)[0]

            anomaly = int(y_pred > 0.5)  # 이진 분류일 경우
            anomaly_buffer.append(anomaly)
            if len(anomaly_buffer) > ANOMALY_THRESHOLD:
                anomaly_buffer.pop(0)

            if anomaly == 1 and anomaly_start_time is None:
                anomaly_start_time = time.perf_counter()
            elif anomaly == 0:
                anomaly_start_time = None

            if postprocess_anomalies_realtime(anomaly_buffer, min_consecutive=ANOMALY_THRESHOLD):
                print("⚡ 아크 이상 감지!", idx)
                if not first_anomaly_detected and anomaly_start_time is not None:
                    total_elapsed = time.perf_counter() - start_time
                    actual_elapsed = time.perf_counter() - anomaly_start_time
                    print(f"⏱️ 전체 소요 시간: {total_elapsed:.6f}초")
                    print(f"⏱️ 연속 이상 감지까지 소요 시간: {actual_elapsed:.6f}초")
                    first_anomaly_detected = True
                    break

        # 로그 저장
        with open(csv_filename, mode='a', newline='') as file:
            writer = csv.writer(file)
            timestamp = datetime.now().isoformat()
            writer.writerow([timestamp, voltage, current, anomaly])

        cpu_usage = psutil.cpu_percent(interval=0.0)
        memory_usage = psutil.Process().memory_info().rss / 1024 ** 2
        print(f"🧠 메모리: {memory_usage:.2f}MB | 🧮 CPU: {cpu_usage:.2f}% | idx: {idx}")
        print(f"Voltage: {voltage:.2f}V, Current: {current:.2f}A, Anomaly: {anomaly}")

        time.sleep(0.001163)

except KeyboardInterrupt:
    print("🛑 실시간 감지를 종료합니다.")
# Out:
# 🚀 LightGBM 기반 실시간 아크 감지 시작!
# 🧠 메모리: 200.45MB | 🧮 CPU: 8.40% | idx: 0
# Voltage: -25.71V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 11.10% | idx: 1
# Voltage: -11.37V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 25.00% | idx: 2
# Voltage: -48.66V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 3
# Voltage: -3.39V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 4
# Voltage: -6.26V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 5
# Voltage: -15.49V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 11.10% | idx: 6
# Voltage: -16.24V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 7
# Voltage: -9.00V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 8
# Voltage: -5.51V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 9
# Voltage: -7.63V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 10
# Voltage: -29.95V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 11
# Voltage: -12.49V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 12
# Voltage: -5.51V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 13
# Voltage: -7.01V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 14
# Voltage: -6.26V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 15
# Voltage: -3.27V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 16
# Voltage: -11.62V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 17
# Voltage: -4.39V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 18
# Voltage: -4.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 25.00% | idx: 19
# Voltage: -12.74V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 20
# Voltage: -13.62V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 21
# Voltage: -7.51V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 22
# Voltage: -5.39V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 23
# Voltage: -14.86V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 25.00% | idx: 24
# Voltage: -5.14V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 25
# Voltage: -2.89V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 26
# Voltage: -5.64V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 27
# Voltage: -8.75V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 28
# Voltage: 1.60V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 29
# Voltage: -5.51V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 27.30% | idx: 30
# Voltage: -28.08V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 31
# Voltage: -16.73V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 32
# Voltage: -7.38V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 33
# Voltage: -8.26V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 34
# Voltage: -5.76V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 35
# Voltage: -6.76V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 36
# Voltage: -12.99V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 9.10% | idx: 37
# Voltage: -5.51V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 38
# Voltage: -5.26V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 39
# Voltage: -4.26V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 40
# Voltage: -5.51V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 41
# Voltage: -12.00V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 42
# Voltage: -12.25V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 9.10% | idx: 43
# Voltage: -6.88V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 44
# Voltage: -16.36V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 45
# Voltage: -8.13V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 46
# Voltage: -3.27V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 47
# Voltage: -6.63V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 48
# Voltage: -4.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 38.50% | idx: 49
# Voltage: -69.11V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 25.00% | idx: 50
# Voltage: -1.52V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 51
# Voltage: -8.63V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 52
# Voltage: -5.14V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 53
# Voltage: -4.02V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 54
# Voltage: -5.64V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 55
# Voltage: -4.76V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 56
# Voltage: -7.76V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 57
# Voltage: -7.76V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 58
# Voltage: -13.62V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 9.10% | idx: 59
# Voltage: -5.26V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 60
# Voltage: -6.01V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 61
# Voltage: -7.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 9.10% | idx: 62
# Voltage: -3.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 63
# Voltage: -6.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 64
# Voltage: -3.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 65
# Voltage: -9.13V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 16.70% | idx: 66
# Voltage: -8.88V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 67
# Voltage: -6.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 20.00% | idx: 68
# Voltage: -20.48V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 9.10% | idx: 69
# Voltage: -2.39V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 70
# Voltage: -7.01V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 71
# Voltage: -7.13V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 72
# Voltage: -11.62V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 73
# Voltage: -16.11V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 18.20% | idx: 74
# Voltage: -9.38V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 0.00% | idx: 75
# Voltage: -5.89V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 76
# Voltage: -6.01V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 77
# Voltage: -7.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 9.10% | idx: 78
# Voltage: -4.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.45MB | 🧮 CPU: 10.00% | idx: 79
# Voltage: -7.01V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 25.00% | idx: 80
# Voltage: -4.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 81
# Voltage: -8.75V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 82
# Voltage: -7.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 83
# Voltage: -8.01V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 84
# Voltage: -5.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 85
# Voltage: -3.39V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 86
# Voltage: -6.38V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 87
# Voltage: -5.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 88
# Voltage: -16.86V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 89
# Voltage: -14.86V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 90
# Voltage: -9.13V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 91
# Voltage: -9.88V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 92
# Voltage: -4.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 93
# Voltage: -3.39V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 94
# Voltage: -2.27V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 95
# Voltage: -5.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 96
# Voltage: -17.73V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 97
# Voltage: -11.25V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 98
# Voltage: -7.26V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 99
# Voltage: -6.01V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 100
# Voltage: -7.13V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 101
# Voltage: -5.26V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 102
# Voltage: -8.50V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 103
# Voltage: -1.15V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 104
# Voltage: -8.01V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 105
# Voltage: -9.63V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 27.30% | idx: 106
# Voltage: -8.88V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 107
# Voltage: -2.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 108
# Voltage: -4.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 109
# Voltage: -7.38V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 110
# Voltage: -2.77V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 111
# Voltage: -4.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 112
# Voltage: -5.26V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 113
# Voltage: -7.88V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 114
# Voltage: -1.40V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 115
# Voltage: -5.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 10.00% | idx: 116
# Voltage: -6.63V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 117
# Voltage: -6.63V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 118
# Voltage: 3.84V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 119
# Voltage: 0.22V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 120
# Voltage: -8.75V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 121
# Voltage: -11.00V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 122
# Voltage: -2.02V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 123
# Voltage: -6.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 21.40% | idx: 124
# Voltage: -4.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 125
# Voltage: -9.38V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 126
# Voltage: -3.39V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 127
# Voltage: -5.01V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 128
# Voltage: -7.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 129
# Voltage: -12.99V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 130
# Voltage: -1.90V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 131
# Voltage: -4.64V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 132
# Voltage: -1.52V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 133
# Voltage: -4.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 134
# Voltage: -5.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 135
# Voltage: -8.88V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 136
# Voltage: -3.02V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 137
# Voltage: -3.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 138
# Voltage: -2.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 139
# Voltage: -4.26V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 140
# Voltage: -1.77V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 30.80% | idx: 141
# Voltage: -12.99V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 142
# Voltage: -9.63V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 143
# Voltage: 0.35V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 144
# Voltage: -0.15V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 145
# Voltage: -7.13V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 146
# Voltage: -7.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 147
# Voltage: -5.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 21.40% | idx: 148
# Voltage: -2.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 149
# Voltage: -3.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 150
# Voltage: -13.99V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 151
# Voltage: -3.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 152
# Voltage: -5.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 153
# Voltage: -2.52V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 154
# Voltage: -18.98V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 155
# Voltage: -2.52V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 156
# Voltage: -3.52V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 157
# Voltage: -4.02V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 158
# Voltage: -4.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 159
# Voltage: 0.35V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 160
# Voltage: -1.27V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 161
# Voltage: -2.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 162
# Voltage: -4.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 163
# Voltage: -5.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 164
# Voltage: -4.14V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 165
# Voltage: -1.65V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 166
# Voltage: -3.52V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 167
# Voltage: -2.52V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 168
# Voltage: -3.52V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 169
# Voltage: -1.65V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 170
# Voltage: -3.27V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 171
# Voltage: -16.24V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 172
# Voltage: -4.64V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 20.00% | idx: 173
# Voltage: -2.89V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 174
# Voltage: -2.77V, Current: 0.23A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 175
# Voltage: -6.51V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 176
# Voltage: -4.02V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 21.40% | idx: 177
# Voltage: -4.76V, Current: 0.24A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 178
# Voltage: -5.14V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 179
# Voltage: -6.76V, Current: 0.25A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 13.30% | idx: 180
# Voltage: -7.26V, Current: 0.26A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 7.70% | idx: 181
# Voltage: -3.14V, Current: 0.30A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 182
# Voltage: -9.13V, Current: 0.34A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 21.40% | idx: 183
# Voltage: -17.73V, Current: 0.47A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 184
# Voltage: -5.51V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 7.70% | idx: 185
# Voltage: -2.64V, Current: 0.64A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 20.00% | idx: 186
# Voltage: -1.65V, Current: 0.61A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 7.70% | idx: 187
# Voltage: -1.40V, Current: 0.62A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 188
# Voltage: -2.39V, Current: 0.61A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 18.20% | idx: 189
# Voltage: -18.98V, Current: 0.56A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 190
# Voltage: -18.23V, Current: 0.55A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 191
# Voltage: -4.64V, Current: 0.55A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 192
# Voltage: -2.39V, Current: 0.55A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 7.70% | idx: 193
# Voltage: -0.65V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 28.60% | idx: 194
# Voltage: -5.01V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 195
# Voltage: -2.89V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 196
# Voltage: -4.14V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 197
# Voltage: -2.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 198
# Voltage: -6.14V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 21.40% | idx: 199
# Voltage: -4.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 200
# Voltage: -4.02V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 201
# Voltage: -3.14V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 202
# Voltage: -3.64V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 203
# Voltage: -12.49V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 204
# Voltage: -4.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 28.60% | idx: 205
# Voltage: -3.89V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 206
# Voltage: -4.89V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 207
# Voltage: -4.26V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 208
# Voltage: -3.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 209
# Voltage: -4.76V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 210
# Voltage: -4.64V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 211
# Voltage: -10.13V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 212
# Voltage: -5.26V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 213
# Voltage: -7.38V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 214
# Voltage: -10.13V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 215
# Voltage: -3.89V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 216
# Voltage: -0.27V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 217
# Voltage: -3.52V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 218
# Voltage: -2.27V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 219
# Voltage: -3.64V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 220
# Voltage: -2.39V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 221
# Voltage: -2.64V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 222
# Voltage: -4.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 223
# Voltage: -2.77V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 224
# Voltage: -1.40V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 21.40% | idx: 225
# Voltage: -9.00V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 226
# Voltage: -10.25V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 227
# Voltage: -3.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 16.70% | idx: 228
# Voltage: -2.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 229
# Voltage: -3.64V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 230
# Voltage: -5.51V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 231
# Voltage: -3.14V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 232
# Voltage: -3.14V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 233
# Voltage: -2.89V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 234
# Voltage: -2.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 235
# Voltage: -4.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 0.00% | idx: 236
# Voltage: -3.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 237
# Voltage: -3.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 23.10% | idx: 238
# Voltage: -18.85V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 239
# Voltage: -8.13V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 240
# Voltage: -4.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 15.40% | idx: 241
# Voltage: -4.14V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 9.10% | idx: 242
# Voltage: -3.64V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.57MB | 🧮 CPU: 8.30% | idx: 243
# Voltage: -3.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 244
# Voltage: -3.64V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 245
# Voltage: -0.27V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 246
# Voltage: -3.89V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 247
# Voltage: -1.65V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 248
# Voltage: -4.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 249
# Voltage: -1.77V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 250
# Voltage: -5.26V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 251
# Voltage: -2.39V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 252
# Voltage: -13.62V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 253
# Voltage: -2.89V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 30.80% | idx: 254
# Voltage: -11.25V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 255
# Voltage: -2.64V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 256
# Voltage: 0.10V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 257
# Voltage: -5.89V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 258
# Voltage: -2.39V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 259
# Voltage: -4.14V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 25.00% | idx: 260
# Voltage: -26.96V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 261
# Voltage: -2.77V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 262
# Voltage: 0.10V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 263
# Voltage: -2.89V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 264
# Voltage: -4.39V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 265
# Voltage: -3.89V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 266
# Voltage: -1.77V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 267
# Voltage: -4.89V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 268
# Voltage: -7.38V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 269
# Voltage: -11.37V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 270
# Voltage: -9.50V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 26.70% | idx: 271
# Voltage: -10.25V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 272
# Voltage: -5.14V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 273
# Voltage: -0.90V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 274
# Voltage: -1.15V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 14.30% | idx: 275
# Voltage: -3.02V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 276
# Voltage: -1.52V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 14.30% | idx: 277
# Voltage: -4.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 278
# Voltage: -2.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 279
# Voltage: -1.90V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 280
# Voltage: -3.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 281
# Voltage: -11.12V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 282
# Voltage: -10.38V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 283
# Voltage: -1.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 284
# Voltage: -5.51V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 285
# Voltage: -25.46V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 286
# Voltage: 289.78V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 287
# Voltage: 227.93V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 288
# Voltage: 370.83V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 289
# Voltage: 322.57V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 290
# Voltage: 188.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 291
# Voltage: -75.09V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 292
# Voltage: -370.63V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 293
# Voltage: -294.57V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 294
# Voltage: -50.65V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 295
# Voltage: 38.88V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 296
# Voltage: 172.68V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 297
# Voltage: 341.03V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 298
# Voltage: 300.88V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 299
# Voltage: -64.12V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 300
# Voltage: -370.76V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 301
# Voltage: -230.22V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 302
# Voltage: 188.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 28.60% | idx: 303
# Voltage: 345.89V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 304
# Voltage: 313.35V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 305
# Voltage: 136.77V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 306
# Voltage: -211.39V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 307
# Voltage: -379.86V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 308
# Voltage: -191.56V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 25.00% | idx: 309
# Voltage: 171.06V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 310
# Voltage: 371.96V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 311
# Voltage: 364.22V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 312
# Voltage: 240.52V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 313
# Voltage: -43.92V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 314
# Voltage: -306.16V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 315
# Voltage: -353.55V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 316
# Voltage: -80.83V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 317
# Voltage: 249.50V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 318
# Voltage: 367.59V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 35.70% | idx: 319
# Voltage: 267.46V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 41.70% | idx: 320
# Voltage: 170.56V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 57.10% | idx: 321
# Voltage: 51.97V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 42.90% | idx: 322
# Voltage: 195.26V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 36.40% | idx: 323
# Voltage: 301.13V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 324
# Voltage: -307.29V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 325
# Voltage: 7.58V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 326
# Voltage: 230.42V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 327
# Voltage: -368.14V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 328
# Voltage: 356.87V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 329
# Voltage: -294.44V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 330
# Voltage: 138.27V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 331
# Voltage: 28.28V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 332
# Voltage: -278.36V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 333
# Voltage: 362.98V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 334
# Voltage: -362.78V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 335
# Voltage: 265.21V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 336
# Voltage: -43.30V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 337
# Voltage: -187.57V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 338
# Voltage: 312.22V, Current: 0.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 339
# Voltage: -374.50V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 340
# Voltage: 322.20V, Current: 2.03A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 341
# Voltage: -117.37V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 342
# Voltage: -80.33V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 343
# Voltage: 246.63V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 344
# Voltage: -343.57V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 345
# Voltage: 367.09V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 346
# Voltage: -342.45V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 347
# Voltage: 200.12V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 348
# Voltage: -68.86V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 349
# Voltage: -216.13V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 350
# Voltage: 343.52V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 351
# Voltage: -379.61V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 352
# Voltage: 282.67V, Current: 2.35A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 353
# Voltage: -94.17V, Current: 0.03A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 354
# Voltage: -81.83V, Current: -0.09A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 355
# Voltage: 263.84V, Current: 2.32A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 356
# Voltage: -374.50V, Current: -1.86A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 357
# Voltage: 314.47V, Current: 2.50A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 358
# Voltage: 109.34V, Current: 1.50A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 359
# Voltage: -375.12V, Current: -1.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 360
# Voltage: 284.67V, Current: 2.31A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 361
# Voltage: -130.46V, Current: -0.06A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 362
# Voltage: -67.99V, Current: 0.01A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 363
# Voltage: 219.70V, Current: 2.17A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 364
# Voltage: -379.36V, Current: -1.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 365
# Voltage: 261.47V, Current: 2.17A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 366
# Voltage: -101.28V, Current: -0.96A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 367
# Voltage: 16.81V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 368
# Voltage: 88.64V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 369
# Voltage: -204.78V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 370
# Voltage: 290.65V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 371
# Voltage: -360.53V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 372
# Voltage: 345.02V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 373
# Voltage: -271.50V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 374
# Voltage: 43.99V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 375
# Voltage: 111.71V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 376
# Voltage: -241.19V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 377
# Voltage: 321.58V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 378
# Voltage: -374.87V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 379
# Voltage: 359.24V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 380
# Voltage: -273.74V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 381
# Voltage: 15.19V, Current: -0.45A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 382
# Voltage: 75.79V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 383
# Voltage: -255.91V, Current: -1.02A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 384
# Voltage: 342.90V, Current: 2.80A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 385
# Voltage: -372.50V, Current: -1.84A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 386
# Voltage: 327.31V, Current: 2.54A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 387
# Voltage: -133.08V, Current: -0.38A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 388
# Voltage: -58.63V, Current: 0.11A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 389
# Voltage: 271.57V, Current: 2.34A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 390
# Voltage: -348.94V, Current: -1.71A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 391
# Voltage: 298.13V, Current: 2.75A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 392
# Voltage: -270.13V, Current: -1.10A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 393
# Voltage: 47.74V, Current: 0.73A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 394
# Voltage: 160.09V, Current: 1.70A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 395
# Voltage: -299.30V, Current: -1.44A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 396
# Voltage: 360.11V, Current: 2.89A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 397
# Voltage: -309.16V, Current: -1.24A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 398
# Voltage: 134.78V, Current: 1.30A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 399
# Voltage: 43.00V, Current: 0.96A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 400
# Voltage: -204.91V, Current: -0.89A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 401
# Voltage: 314.34V, Current: 2.63A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 402
# Voltage: -373.75V, Current: -1.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 403
# Voltage: 329.68V, Current: 2.75A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 404
# Voltage: -296.56V, Current: -1.12A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 405
# Voltage: 24.04V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 406
# Voltage: 147.62V, Current: 1.63A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 407
# Voltage: -291.82V, Current: -1.38A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 408
# Voltage: 421.59V, Current: 2.57A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 409
# Voltage: -438.84V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 410
# Voltage: 288.03V, Current: 0.56A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 411
# Voltage: -137.69V, Current: -0.31A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 412
# Voltage: -116.74V, Current: -0.40A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 413
# Voltage: 301.87V, Current: 2.72A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 414
# Voltage: -368.89V, Current: -1.84A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 415
# Voltage: 298.13V, Current: 2.42A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 416
# Voltage: -158.89V, Current: 0.14A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 417
# Voltage: -106.39V, Current: -0.22A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 418
# Voltage: 248.13V, Current: 2.25A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 419
# Voltage: -352.93V, Current: -1.73A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 420
# Voltage: 333.67V, Current: 2.82A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 421
# Voltage: -255.16V, Current: -0.99A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 422
# Voltage: 79.03V, Current: 1.02A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 423
# Voltage: 76.79V, Current: 1.12A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 424
# Voltage: -237.58V, Current: -1.06A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 425
# Voltage: 333.42V, Current: 2.72A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 426
# Voltage: -375.00V, Current: -1.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 427
# Voltage: 320.95V, Current: 2.59A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 428
# Voltage: -153.03V, Current: -0.02A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 429
# Voltage: -154.15V, Current: -0.55A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 430
# Voltage: 298.26V, Current: 2.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 431
# Voltage: -374.12V, Current: -1.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 432
# Voltage: 294.39V, Current: 2.36A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 433
# Voltage: -164.50V, Current: -0.34A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 434
# Voltage: -99.04V, Current: -0.18A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 435
# Voltage: 227.68V, Current: 2.15A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 436
# Voltage: -360.66V, Current: -1.82A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 437
# Voltage: 331.55V, Current: 2.55A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 438
# Voltage: -150.54V, Current: -1.07A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 439
# Voltage: 11.95V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 440
# Voltage: 219.20V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 441
# Voltage: -377.87V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 442
# Voltage: 158.72V, Current: 1.55A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 443
# Voltage: 3.34V, Current: 0.65A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 444
# Voltage: -251.42V, Current: -1.13A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 445
# Voltage: 351.88V, Current: 2.86A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 446
# Voltage: -358.79V, Current: -1.73A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 447
# Voltage: 250.75V, Current: 2.09A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 448
# Voltage: -103.03V, Current: 0.05A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 449
# Voltage: -91.06V, Current: -0.11A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 450
# Voltage: 281.17V, Current: 2.58A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 451
# Voltage: -375.00V, Current: -1.86A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 452
# Voltage: 280.43V, Current: 2.21A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 453
# Voltage: -179.34V, Current: -0.46A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 454
# Voltage: -48.53V, Current: 0.15A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 455
# Voltage: 166.70V, Current: 1.79A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 456
# Voltage: -294.94V, Current: -1.38A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 457
# Voltage: 346.39V, Current: 2.80A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 458
# Voltage: -375.00V, Current: -1.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 459
# Voltage: 330.80V, Current: 2.64A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 460
# Voltage: -232.84V, Current: -0.76A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 461
# Voltage: 70.80V, Current: 1.08A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 462
# Voltage: 41.13V, Current: 0.93A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 463
# Voltage: -182.46V, Current: -1.09A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 464
# Voltage: 292.77V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 465
# Voltage: -381.73V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 466
# Voltage: 356.62V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 467
# Voltage: -301.92V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 468
# Voltage: 116.44V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 469
# Voltage: 148.49V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 470
# Voltage: -360.41V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 471
# Voltage: 365.22V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 472
# Voltage: -328.36V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 473
# Voltage: 177.17V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 474
# Voltage: 35.14V, Current: 0.13A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 475
# Voltage: -252.29V, Current: 0.78A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 476
# Voltage: 330.80V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 477
# Voltage: -296.56V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 478
# Voltage: 150.99V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 479
# Voltage: 45.12V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 480
# Voltage: -241.94V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 481
# Voltage: 333.67V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 482
# Voltage: -376.37V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 483
# Voltage: 352.25V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 484
# Voltage: -295.69V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 485
# Voltage: 73.55V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 486
# Voltage: 80.28V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 487
# Voltage: -225.48V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 488
# Voltage: 310.60V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 489
# Voltage: -374.87V, Current: -1.86A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 490
# Voltage: 322.95V, Current: 2.59A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 491
# Voltage: -248.93V, Current: -0.92A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 492
# Voltage: 44.24V, Current: 0.58A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 493
# Voltage: 233.66V, Current: 2.20A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 494
# Voltage: -335.22V, Current: -1.65A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 495
# Voltage: 361.11V, Current: 2.89A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 496
# Voltage: -349.68V, Current: -1.66A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 497
# Voltage: 189.27V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 498
# Voltage: -159.14V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 18.20% | idx: 499
# Voltage: -9.88V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 500
# Voltage: 187.77V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 501
# Voltage: -350.68V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 25.00% | idx: 502
# Voltage: 367.47V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 503
# Voltage: -356.29V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 25.00% | idx: 504
# Voltage: 258.73V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 505
# Voltage: -151.54V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 506
# Voltage: -17.98V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 507
# Voltage: 146.37V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 25.00% | idx: 508
# Voltage: -370.13V, Current: -1.76A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 509
# Voltage: 295.76V, Current: 2.25A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 10.00% | idx: 510
# Voltage: -25.84V, Current: 0.48A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 511
# Voltage: -193.43V, Current: -0.80A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 512
# Voltage: 321.83V, Current: 2.66A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 7.70% | idx: 513
# Voltage: 296.01V, Current: 2.90A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 14.30% | idx: 514
# Voltage: 367.34V, Current: 2.44A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 515
# Voltage: 114.45V, Current: -0.01A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 516
# Voltage: 323.57V, Current: 2.03A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 517
# Voltage: 292.65V, Current: 2.85A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 518
# Voltage: -70.36V, Current: 0.97A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 519
# Voltage: -231.22V, Current: -0.17A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 520
# Voltage: -367.77V, Current: -1.57A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 521
# Voltage: -311.40V, Current: -1.76A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 522
# Voltage: -190.82V, Current: -1.34A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 523
# Voltage: 88.64V, Current: 0.16A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 524
# Voltage: 342.53V, Current: 2.34A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 525
# Voltage: 295.64V, Current: 2.79A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 526
# Voltage: 159.59V, Current: 2.31A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 527
# Voltage: -190.32V, Current: 0.17A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 528
# Voltage: -363.40V, Current: -1.46A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 529
# Voltage: -301.42V, Current: -1.74A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 530
# Voltage: -81.08V, Current: -0.82A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 531
# Voltage: 257.85V, Current: 1.42A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 532
# Voltage: 338.04V, Current: 2.31A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 533
# Voltage: 335.17V, Current: 2.89A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 534
# Voltage: 138.77V, Current: 2.19A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 535
# Voltage: -243.94V, Current: -0.23A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 536
# Voltage: -369.01V, Current: -1.65A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 537
# Voltage: -268.01V, Current: -1.64A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 538
# Voltage: 142.63V, Current: 0.48A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 539
# Voltage: 360.36V, Current: 2.69A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 540
# Voltage: 162.83V, Current: 2.29A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 541
# Voltage: -256.16V, Current: -0.02A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 28.60% | idx: 542
# Voltage: -370.76V, Current: -1.72A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 543
# Voltage: -378.12V, Current: -1.72A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 544
# Voltage: -369.26V, Current: 0.52A, Anomaly: 1
# 🧠 메모리: 200.70MB | 🧮 CPU: 20.00% | idx: 545
# Voltage: -376.00V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 14.30% | idx: 546
# Voltage: -367.02V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 547
# Voltage: -374.62V, Current: 0.52A, Anomaly: 1
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 548
# Voltage: -222.86V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 549
# Voltage: 197.50V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 550
# Voltage: 360.98V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 26.70% | idx: 551
# Voltage: 334.55V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 552
# Voltage: 148.49V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 553
# Voltage: -113.63V, Current: 0.21A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 554
# Voltage: -372.01V, Current: -1.62A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 555
# Voltage: -196.68V, Current: -1.10A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 556
# Voltage: 222.94V, Current: 1.14A, Anomaly: 1
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 557
# Voltage: 373.45V, Current: 2.78A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 558
# Voltage: 195.38V, Current: 2.38A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 559
# Voltage: -100.03V, Current: 0.80A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 560
# Voltage: -328.73V, Current: -0.98A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 561
# Voltage: -302.30V, Current: -1.76A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 562
# Voltage: 80.78V, Current: 0.21A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 563
# Voltage: 264.21V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 564
# Voltage: 332.18V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 565
# Voltage: 120.44V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 566
# Voltage: -171.74V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 567
# Voltage: -377.62V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 568
# Voltage: -201.42V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 569
# Voltage: 206.85V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 570
# Voltage: 362.98V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 571
# Voltage: 238.15V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 572
# Voltage: -50.15V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 573
# Voltage: -324.99V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 574
# Voltage: -374.12V, Current: -1.75A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 575
# Voltage: -291.82V, Current: -1.75A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 576
# Voltage: -198.42V, Current: -1.34A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 577
# Voltage: 14.94V, Current: 1.09A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 578
# Voltage: 198.87V, Current: 1.04A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 579
# Voltage: 367.34V, Current: 2.63A, Anomaly: 1
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 580
# Voltage: 186.28V, Current: 2.39A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 581
# Voltage: -224.24V, Current: -0.08A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 582
# Voltage: -364.27V, Current: -1.84A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 583
# Voltage: -67.86V, Current: -1.00A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 584
# Voltage: 221.57V, Current: 0.68A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 585
# Voltage: 184.28V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 586
# Voltage: 251.74V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 587
# Voltage: 363.48V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 588
# Voltage: 360.36V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 589
# Voltage: 219.07V, Current: 0.52A, Anomaly: 1
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 590
# Voltage: -24.47V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 591
# Voltage: -308.03V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 592
# Voltage: -377.74V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 593
# Voltage: -346.57V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 594
# Voltage: -243.19V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 595
# Voltage: 50.60V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 596
# Voltage: 330.18V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 597
# Voltage: 328.93V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 598
# Voltage: 39.26V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 599
# Voltage: -223.24V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 600
# Voltage: -382.73V, Current: 0.53A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 601
# Voltage: -221.49V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 602
# Voltage: 71.93V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 603
# Voltage: 268.33V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 604
# Voltage: 363.60V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 605
# Voltage: 142.38V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 606
# Voltage: -80.58V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 607
# Voltage: -306.66V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 608
# Voltage: -377.49V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 609
# Voltage: -214.88V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 610
# Voltage: 204.11V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 611
# Voltage: 366.84V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 612
# Voltage: 90.26V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 613
# Voltage: -307.41V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 614
# Voltage: -372.38V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 615
# Voltage: -78.34V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 616
# Voltage: 168.94V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 617
# Voltage: 299.01V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 618
# Voltage: 371.33V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 14.30% | idx: 619
# Voltage: 361.73V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 620
# Voltage: 324.57V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 14.30% | idx: 621
# Voltage: 371.71V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 622
# Voltage: 361.61V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 623
# Voltage: 63.32V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 624
# Voltage: -229.10V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 625
# Voltage: -368.01V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 626
# Voltage: -115.25V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 627
# Voltage: 257.98V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 628
# Voltage: 9.70V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 629
# Voltage: -1.52V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 630
# Voltage: -6.38V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 631
# Voltage: -4.64V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 632
# Voltage: -11.37V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 633
# Voltage: -3.77V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 634
# Voltage: -4.14V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 635
# Voltage: -3.89V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 636
# Voltage: -3.77V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 637
# Voltage: -5.01V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 638
# Voltage: -3.64V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 639
# Voltage: -5.51V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 640
# Voltage: -2.39V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 641
# Voltage: -13.24V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 642
# Voltage: -1.27V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 643
# Voltage: -8.13V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 644
# Voltage: -2.39V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 645
# Voltage: -5.26V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 646
# Voltage: -1.65V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 647
# Voltage: -4.26V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 33.30% | idx: 648
# Voltage: -3.14V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 649
# Voltage: -10.00V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 9.10% | idx: 650
# Voltage: -1.52V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 651
# Voltage: -4.14V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 652
# Voltage: -2.89V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 0.00% | idx: 653
# Voltage: -12.00V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 23.10% | idx: 654
# Voltage: -8.26V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 655
# Voltage: -8.26V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 656
# Voltage: -0.90V, Current: 0.51A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 15.40% | idx: 657
# Voltage: -2.52V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 21.40% | idx: 658
# Voltage: -10.50V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 16.70% | idx: 659
# Voltage: -4.51V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 8.30% | idx: 660
# Voltage: -1.40V, Current: 0.52A, Anomaly: 0
# 🧠 메모리: 200.70MB | 🧮 CPU: 35.70% | idx: 661
# Voltage: -11.25V, Current: 0.52A, Anomaly: 0
# 🛑 실시간 감지를 종료합니다.
